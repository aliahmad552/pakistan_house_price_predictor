# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Cleaned_data.csv")

# %%
df.head()
# Out:
#    Unnamed: 0     location property_type       city  baths   purpose  \
# 0           0         G-10          Flat  Islamabad      2  For Sale
# 1           1         E-11          Flat  Islamabad      3  For Sale
# 2           2         G-15         House  Islamabad      6  For Sale
# 3           4  DHA Defence         House  Islamabad      3  For Sale
# 4           5         E-11          Flat  Islamabad      2  For Sale
#
#    bedrooms  Area_in_Marla     price
# 0         2            4.0  10000000
# 1         3            5.6   6900000
# 2         5            8.0  16500000
# 3         3            8.0   7000000
# 4         2            6.2   7800000

# %%
df = df[df['purpose'] == 'For Rent']

# %%
df.head()
# Out:
#     Unnamed: 0     location  property_type       city  baths   purpose  \
# 21          22  DHA Defence          House  Islamabad      5  For Rent
# 22          24         G-15  Lower Portion  Islamabad      2  For Rent
# 23          25       others          House  Islamabad      5  For Rent
# 24          26          F-7          House  Islamabad      4  For Rent
# 25          27       others  Lower Portion  Islamabad      2  For Rent
#
#     bedrooms  Area_in_Marla   price
# 21         5           20.0  110000
# 22         2            8.0   33000
# 23         3           24.0   45000
# 24         4           13.3  175000
# 25         2            5.0   17000
